# %% [markdown]
# <u>**Used Car Pricing Analysis**<u>
#
# As part of IBM's Data Analysis in Python Course

# %%
#Importing libraries
import pandas as pd
import numpy as np
import matplotlib.pylab as plt

# %% [markdown]
# Reading in Data

# %%
df = pd.read_csv('used_car_dataset.data')

# %%
df.head()
# Out:
#    3    ?  alfa-romero  gas  std   two  convertible  rwd  front  88.60  ...  \
# 0  3    ?  alfa-romero  gas  std   two  convertible  rwd  front   88.6  ...
# 1  1    ?  alfa-romero  gas  std   two    hatchback  rwd  front   94.5  ...
# 2  2  164         audi  gas  std  four        sedan  fwd  front   99.8  ...
# 3  2  164         audi  gas  std  four        sedan  4wd  front   99.4  ...
# 4  2    ?         audi  gas  std   two        sedan  fwd  front   99.8  ...
#
#    130  mpfi  3.47  2.68  9.00  111  5000  21  27  13495
# 0  130  mpfi  3.47  2.68   9.0  111  5000  21  27  16500
# 1  152  mpfi  2.68  3.47   9.0  154  5000  19  26  16500
# 2  109  mpfi  3.19  3.40  10.0  102  5500  24  30  13950
# 3  136  mpfi  3.19  3.40   8.0  115  5500  18  22  17450
# 4  136  mpfi  3.19  3.40   8.5  110  5500  19  25  15250
#
# [5 rows x 26 columns]

# %%
# Adding headers
headers = ["symboling","normalized-losses","make","fuel-type","aspiration", "num-of-doors","body-style",
         "drive-wheels","engine-location","wheel-base", "length","width","height","curb-weight","engine-type",
         "num-of-cylinders", "engine-size","fuel-system","bore","stroke","compression-ratio","horsepower",
         "peak-rpm","city-mpg","highway-mpg","price"]
print("headers\n", headers)
# Out:
# headers
#  ['symboling', 'normalized-losses', 'make', 'fuel-type', 'aspiration', 'num-of-doors', 'body-style', 'drive-wheels', 'engine-location', 'wheel-base', 'length', 'width', 'height', 'curb-weight', 'engine-type', 'num-of-cylinders', 'engine-size', 'fuel-system', 'bore', 'stroke', 'compression-ratio', 'horsepower', 'peak-rpm', 'city-mpg', 'highway-mpg', 'price']

# %%
df.columns = headers
df.columns
# Out:
# Index(['symboling', 'normalized-losses', 'make', 'fuel-type', 'aspiration',
#        'num-of-doors', 'body-style', 'drive-wheels', 'engine-location',
#        'wheel-base', 'length', 'width', 'height', 'curb-weight', 'engine-type',
#        'num-of-cylinders', 'engine-size', 'fuel-system', 'bore', 'stroke',
#        'compression-ratio', 'horsepower', 'peak-rpm', 'city-mpg',
#        'highway-mpg', 'price'],
#       dtype='object')

# %%
df.head()
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3                 ?  alfa-romero       gas        std          two
# 1          1                 ?  alfa-romero       gas        std          two
# 2          2               164         audi       gas        std         four
# 3          2               164         audi       gas        std         four
# 4          2                 ?         audi       gas        std          two
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 0  convertible          rwd           front        88.6  ...          130
# 1    hatchback          rwd           front        94.5  ...          152
# 2        sedan          fwd           front        99.8  ...          109
# 3        sedan          4wd           front        99.4  ...          136
# 4        sedan          fwd           front        99.8  ...          136
#
# ...

# %%
# Replacing ? with NaN so we can drop missing values
df1=df.replace('?',np.NaN)

# %%
df=df1.dropna(subset=["price"], axis=0)
df.head(20)
# Out:
#     symboling normalized-losses         make fuel-type aspiration  \
# 0           3               NaN  alfa-romero       gas        std
# 1           1               NaN  alfa-romero       gas        std
# 2           2               164         audi       gas        std
# 3           2               164         audi       gas        std
# 4           2               NaN         audi       gas        std
# 5           1               158         audi       gas        std
# 6           1               NaN         audi       gas        std
# 7           1               158         audi       gas      turbo
# 9           2               192          bmw       gas        std
# 10          0               192          bmw       gas        std
# 11          0               188          bmw       gas        std
# 12          0               188          bmw       gas        std
# 13          1               NaN          bmw       gas        std
# ...

# %% [markdown]
# **Exploratory Data Analysis**

# %%
df.dtypes
# Out:
# symboling              int64
# normalized-losses     object
# make                  object
# fuel-type             object
# aspiration            object
# num-of-doors          object
# body-style            object
# drive-wheels          object
# engine-location       object
# wheel-base           float64
# length               float64
# width                float64
# height               float64
# curb-weight            int64
# engine-type           object
# num-of-cylinders      object
# engine-size            int64
# fuel-system           object
# bore                  object
# stroke                object
# compression-ratio    float64
# horsepower            object
# peak-rpm              object
# city-mpg               int64
# highway-mpg            int64
# price                 object
# dtype: object

# %%
df.describe()
# Out:
#         symboling  wheel-base      length       width      height  \
# count  200.000000  200.000000  200.000000  200.000000  200.000000
# mean     0.830000   98.848000  174.228000   65.898000   53.791500
# std      1.248557    6.038261   12.347132    2.102904    2.428449
# min     -2.000000   86.600000  141.100000   60.300000   47.800000
# 25%      0.000000   94.500000  166.675000   64.175000   52.000000
# 50%      1.000000   97.000000  173.200000   65.500000   54.100000
# 75%      2.000000  102.400000  183.500000   66.675000   55.525000
# max      3.000000  120.900000  208.100000   72.000000   59.800000
#
#        curb-weight  engine-size  compression-ratio    city-mpg  highway-mpg
# count   200.000000   200.000000         200.000000  200.000000   200.000000
# mean   2555.705000   126.860000          10.170100   25.200000    30.705000
# std     518.594552    41.650501           4.014163    6.432487     6.827227
# ...

# %%
df.describe(include='all')
# Out:
#          symboling normalized-losses    make fuel-type aspiration  \
# count   200.000000               164     200       200        200
# unique         NaN                51      22         2          2
# top            NaN               161  toyota       gas        std
# freq           NaN                11      32       180        164
# mean      0.830000               NaN     NaN       NaN        NaN
# std       1.248557               NaN     NaN       NaN        NaN
# min      -2.000000               NaN     NaN       NaN        NaN
# 25%       0.000000               NaN     NaN       NaN        NaN
# 50%       1.000000               NaN     NaN       NaN        NaN
# 75%       2.000000               NaN     NaN       NaN        NaN
# max       3.000000               NaN     NaN       NaN        NaN
#
#        num-of-doors body-style drive-wheels engine-location  wheel-base  ...  \
# count           198        200          200             200  200.000000  ...
# ...

# %%
df[['length', 'compression-ratio']].describe()
# Out:
#            length  compression-ratio
# count  200.000000         200.000000
# mean   174.228000          10.170100
# std     12.347132           4.014163
# min    141.100000           7.000000
# 25%    166.675000           8.575000
# 50%    173.200000           9.000000
# 75%    183.500000           9.400000
# max    208.100000          23.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 200 entries, 0 to 203
# Data columns (total 26 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          200 non-null    int64
#  1   normalized-losses  164 non-null    object
#  2   make               200 non-null    object
#  3   fuel-type          200 non-null    object
#  4   aspiration         200 non-null    object
#  5   num-of-doors       198 non-null    object
#  6   body-style         200 non-null    object
#  7   drive-wheels       200 non-null    object
#  8   engine-location    200 non-null    object
#  9   wheel-base         200 non-null    float64
#  10  length             200 non-null    float64
#  11  width              200 non-null    float64
#  12  height             200 non-null    float64
#  13  curb-weight        200 non-null    int64
#  14  engine-type        200 non-null    object
#  15  num-of-cylinders   200 non-null    object
# ...

# %% [markdown]
# **Data Wrangling**
# Evaluating missing data

# %%
missing_data = df.isnull()

# %%
missing_data.head(10)
# Out:
#     symboling  normalized-losses   make  fuel-type  aspiration  num-of-doors  \
# 0       False               True  False      False       False         False
# 1       False               True  False      False       False         False
# 2       False              False  False      False       False         False
# 3       False              False  False      False       False         False
# 4       False               True  False      False       False         False
# 5       False              False  False      False       False         False
# 6       False               True  False      False       False         False
# 7       False              False  False      False       False         False
# 9       False              False  False      False       False         False
# 10      False              False  False      False       False         False
#
#     body-style  drive-wheels  engine-location  wheel-base  ...  engine-size  \
# ...

# %% [markdown]
# "True" means the value is a missing value while "False" means the value is not a missing value.

# %% [markdown]
# Counting missing values for each column

# %%
for column in missing_data.columns.values.tolist():
    print(column)
    print (missing_data[column].value_counts())
    print("")
# Out:
# symboling
# symboling
# False    200
# Name: count, dtype: int64
#
# normalized-losses
# normalized-losses
# False    164
# True      36
# Name: count, dtype: int64
#
# make
# make
# False    200
# Name: count, dtype: int64
#
# fuel-type
# fuel-type
# False    200
# Name: count, dtype: int64
#
# aspiration
# aspiration
# False    200
# Name: count, dtype: int64
#
# num-of-doors
# num-of-doors
# False    198
# True       2
# Name: count, dtype: int64
#
# body-style
# body-style
# False    200
# Name: count, dtype: int64
#
# drive-wheels
# drive-wheels
# False    200
# Name: count, dtype: int64
#
# engine-location
# engine-location
# False    200
# Name: count, dtype: int64
#
# wheel-base
# wheel-base
# False    200
# Name: count, dtype: int64
#
# length
# length
# False    200
# Name: count, dtype: int64
#
# width
# width
# False    200
# Name: count, dtype: int64
#
# height
# height
# False    200
# Name: count, dtype: int64
#
# curb-weight
# curb-weight
# False    200
# ...

# %%
# Calculating mean for 'normalized losses' column
avg_norm_loss = df["normalized-losses"].astype("float").mean(axis=0)
print("Average of normalized-losses:", avg_norm_loss)
# Out:
# Average of normalized-losses: 122.0

# %%
# Replacing NaN with mean for normalized losses
df["normalized-losses"].replace(np.nan, avg_norm_loss, inplace=True)
# Out:
# C:\Users\vikra\AppData\Local\Temp\ipykernel_19644\1177991778.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["normalized-losses"].replace(np.nan, avg_norm_loss, inplace=True)

# %%
# Calculating mean for 'bore' column
avg_bore=df['bore'].astype('float').mean(axis=0)
print("Average of bore:", avg_bore)
# Out:
# Average of bore: 3.3300000000000005

# %%
# Replacing NaN with mean for bore
df["bore"].replace(np.nan, avg_bore, inplace=True)
# Out:
# C:\Users\vikra\AppData\Local\Temp\ipykernel_19644\2273430268.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["bore"].replace(np.nan, avg_bore, inplace=True)

# %%
#Calculate mean vaule for "stroke" column
avg_stroke = df["stroke"].astype("float").mean(axis = 0)
print("Average of stroke:", avg_stroke)

# replace NaN by mean value for stroke
df["stroke"].replace(np.nan, avg_stroke, inplace = True)
# Out:
# Average of stroke: 3.2598469387755107
# C:\Users\vikra\AppData\Local\Temp\ipykernel_19644\3809090748.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["stroke"].replace(np.nan, avg_stroke, inplace = True)

# %%
# Calculate mean for 'horsepower' column
avg_horsepower = df['horsepower'].astype('float').mean(axis=0)
print("Average horsepower:", avg_horsepower)

#Replace NaN with mean for horsepower
df['horsepower'].replace(np.nan, avg_horsepower, inplace=True)
# Out:
# Average horsepower: 103.35858585858585
# C:\Users\vikra\AppData\Local\Temp\ipykernel_19644\2470440746.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['horsepower'].replace(np.nan, avg_horsepower, inplace=True)

# %%
# Calculate mean for 'peak-rpm' column
avg_peakrpm=df['peak-rpm'].astype('float').mean(axis=0)
print("Average peak rpm:", avg_peakrpm)

# Replace NaN with mean for peak-rpm
df['peak-rpm'].replace(np.nan, avg_peakrpm, inplace=True)
# Out:
# Average peak rpm: 5118.181818181818
# C:\Users\vikra\AppData\Local\Temp\ipykernel_19644\520478652.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['peak-rpm'].replace(np.nan, avg_peakrpm, inplace=True)

# %%
# See which value is most common
df['num-of-doors'].value_counts()
# Out:
# num-of-doors
# four    113
# two      85
# Name: count, dtype: int64

# %%
df['num-of-doors'].value_counts().idxmax()
# Out:
# 'four'

# %%
#replace the missing 'num-of-doors' values by the most frequent (four)
df["num-of-doors"].replace(np.nan, "four", inplace=True)
# Out:
# C:\Users\vikra\AppData\Local\Temp\ipykernel_19644\1144156285.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["num-of-doors"].replace(np.nan, "four", inplace=True)

# %%
# dropping rows with NaN in "price" column
df.dropna(subset=["price"], axis=0, inplace=True)

# reset index, because we droped two rows
df.reset_index(drop=True, inplace=True)
# Out:
# C:\Users\vikra\AppData\Local\Temp\ipykernel_19644\3103434338.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.dropna(subset=["price"], axis=0, inplace=True)

# %%
df.head()
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3             122.0  alfa-romero       gas        std          two
# 1          1             122.0  alfa-romero       gas        std          two
# 2          2               164         audi       gas        std         four
# 3          2               164         audi       gas        std         four
# 4          2             122.0         audi       gas        std          two
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 0  convertible          rwd           front        88.6  ...          130
# 1    hatchback          rwd           front        94.5  ...          152
# 2        sedan          fwd           front        99.8  ...          109
# 3        sedan          4wd           front        99.4  ...          136
# 4        sedan          fwd           front        99.8  ...          136
#
# ...

# %%
df.dtypes
# Out:
# symboling              int64
# normalized-losses     object
# make                  object
# fuel-type             object
# aspiration            object
# num-of-doors          object
# body-style            object
# drive-wheels          object
# engine-location       object
# wheel-base           float64
# length               float64
# width                float64
# height               float64
# curb-weight            int64
# engine-type           object
# num-of-cylinders      object
# engine-size            int64
# fuel-system           object
# bore                  object
# stroke                object
# compression-ratio    float64
# horsepower            object
# peak-rpm              object
# city-mpg               int64
# highway-mpg            int64
# price                 object
# dtype: object

# %%
# Some types are wrong so coverting to correct data types
df[["bore", "stroke"]] = df[["bore", "stroke"]].astype("float")
df[["normalized-losses"]] = df[["normalized-losses"]].astype("int")
df[["price"]] = df[["price"]].astype("float")
df[["peak-rpm"]] = df[["peak-rpm"]].astype("float")
# Out:
# C:\Users\vikra\AppData\Local\Temp\ipykernel_19644\3306858805.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[["bore", "stroke"]] = df[["bore", "stroke"]].astype("float")
# C:\Users\vikra\AppData\Local\Temp\ipykernel_19644\3306858805.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[["normalized-losses"]] = df[["normalized-losses"]].astype("int")
# C:\Users\vikra\AppData\Local\Temp\ipykernel_19644\3306858805.py:4: SettingWithCopyWarning:
# ...

# %% [markdown]
# **Data Standardisation**

# %%
# Transform mpg to L/100km by mathematical operation (235 divided by mpg)
df["highway-mpg"] = 235 / df["highway-mpg"]

# Rename column from "highway-mpg" to "highway-L/100km"
df.rename(columns={'highway-mpg': 'highway-L/100km'}, inplace=True)

# Checking the transformed data
df.head()
# Out:
# C:\Users\vikra\AppData\Local\Temp\ipykernel_19644\363868735.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["highway-mpg"] = 235 / df["highway-mpg"]
# C:\Users\vikra\AppData\Local\Temp\ipykernel_19644\363868735.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.rename(columns={'highway-mpg': 'highway-L/100km'}, inplace=True)
#    symboling  normalized-losses         make fuel-type aspiration  \
# 0          3                122  alfa-romero       gas        std
# 1          1                122  alfa-romero       gas        std
# ...

# %% [markdown]
# **Data Normalisation**

# %%
# Normalizing height column
df['height'] = df['height']/df['height'].max() 

# show the scaled columns
df[["length","width","height"]].head()
# Out:
# C:\Users\vikra\AppData\Local\Temp\ipykernel_19644\940423377.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['height'] = df['height']/df['height'].max()
#    length  width    height
# 0   168.8   64.1  0.816054
# 1   171.2   65.5  0.876254
# 2   176.6   66.2  0.908027
# 3   176.6   66.4  0.908027
# 4   177.3   66.3  0.887960

# %% [markdown]
# **Binning**

# %%
# Horsepower only has 59 values which we can bin into low, medium and high

#Converting dtype
df["horsepower"]=df["horsepower"].astype(int, copy=True)
# Out:
# C:\Users\vikra\AppData\Local\Temp\ipykernel_19644\2913749256.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["horsepower"]=df["horsepower"].astype(int, copy=True)

# %%
# Plotting histogram to see distribution
# %matplotlib inline
import matplotlib as plt
from matplotlib import pyplot
plt.pyplot.hist(df["horsepower"])

# set x/y labels and plot title
plt.pyplot.xlabel("horsepower")
plt.pyplot.ylabel("count")
plt.pyplot.title("horsepower bins")
# Out:
# Text(0.5, 1.0, 'horsepower bins')

# %%
# Finding 3 equally sized bins
bins = np.linspace(min(df["horsepower"]), max(df["horsepower"]), 4)
bins
# Out:
# array([ 48.        , 119.33333333, 190.66666667, 262.        ])

# %%
# Setting bin names
group_names = ['Low', 'Medium', 'High']

# Splitting bins
df['horsepower-binned'] = pd.cut(df['horsepower'], bins, labels=group_names, include_lowest=True )
df[['horsepower','horsepower-binned']].head(20)

# Seeing number of vehicles (rows) in each bin
df["horsepower-binned"].value_counts()
# Out:
# C:\Users\vikra\AppData\Local\Temp\ipykernel_19644\1256601563.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['horsepower-binned'] = pd.cut(df['horsepower'], bins, labels=group_names, include_lowest=True )
# horsepower-binned
# Low       152
# Medium     43
# High        5
# Name: count, dtype: int64

# %%
# Plotting the bins
# %matplotlib inline
import matplotlib as plt
from matplotlib import pyplot
pyplot.bar(group_names, df["horsepower-binned"].value_counts())

# set x/y labels and plot title
plt.pyplot.xlabel("horsepower")
plt.pyplot.ylabel("count")
plt.pyplot.title("horsepower bins")
# Out:
# Text(0.5, 1.0, 'horsepower bins')

# %%
#Visualising the bins as histogram
plt.pyplot.hist(df["horsepower"], bins = 3)

# set x/y labels and plot title
plt.pyplot.xlabel("horsepower")
plt.pyplot.ylabel("count")
plt.pyplot.title("horsepower bins")
# Out:
# Text(0.5, 1.0, 'horsepower bins')

# %% [markdown]
# **Indicator Variables**

# %%
df.columns
# Out:
# Index(['symboling', 'normalized-losses', 'make', 'fuel-type', 'aspiration',
#        'num-of-doors', 'body-style', 'drive-wheels', 'engine-location',
#        'wheel-base', 'length', 'width', 'height', 'curb-weight', 'engine-type',
#        'num-of-cylinders', 'engine-size', 'fuel-system', 'bore', 'stroke',
#        'compression-ratio', 'horsepower', 'peak-rpm', 'city-mpg',
#        'highway-L/100km', 'price', 'horsepower-binned'],
#       dtype='object')

# %%
# Convert 'fuel-type' to dummy variables
dummy_variable_1 = pd.get_dummies(df["fuel-type"])

# Use only the 'diesel' column, because it gives 1 for diesel and 0 for gas
df["fuel-type-binary"] = dummy_variable_1["diesel"].astype(int)  # Convert True/False to 1/0

# Drop the original 'fuel-type' column
df.drop("fuel-type", axis=1, inplace=True)

# View the transformed DataFrame
df.head()
# Out:
# C:\Users\vikra\AppData\Local\Temp\ipykernel_19644\3498677569.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["fuel-type-binary"] = dummy_variable_1["diesel"].astype(int)  # Convert True/False to 1/0
# C:\Users\vikra\AppData\Local\Temp\ipykernel_19644\3498677569.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop("fuel-type", axis=1, inplace=True)
#    symboling  normalized-losses         make aspiration num-of-doors  \
# 0          3                122  alfa-romero        std          two
# ...

# %%
# Convert 'aspiration' to dummy variables
dummy_variable_aspiration = pd.get_dummies(df["aspiration"], prefix='aspiration')

# Use the 'turbo' column (or whichever is applicable) to create a binary column
df["aspiration-binary"] = dummy_variable_aspiration["aspiration_turbo"].astype(int)  # Assuming 'turbo' column exists

# Drop the original 'aspiration' column
df.drop("aspiration", axis=1, inplace=True)

# View the transformed DataFrame
df.head()
# Out:
# C:\Users\vikra\AppData\Local\Temp\ipykernel_19644\2200179240.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["aspiration-binary"] = dummy_variable_aspiration["aspiration_turbo"].astype(int)  # Assuming 'turbo' column exists
# C:\Users\vikra\AppData\Local\Temp\ipykernel_19644\2200179240.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop("aspiration", axis=1, inplace=True)
#    symboling  normalized-losses         make num-of-doors   body-style  \
# 0          3                122  alfa-romero          two  convertible
# ...

# %%
df.tail()
# Out:
#      symboling  normalized-losses   make num-of-doors body-style drive-wheels  \
# 195         -1                 95  volvo         four      sedan          rwd
# 196         -1                 95  volvo         four      sedan          rwd
# 197         -1                 95  volvo         four      sedan          rwd
# 198         -1                 95  volvo         four      sedan          rwd
# 199         -1                 95  volvo         four      sedan          rwd
#
#     engine-location  wheel-base  length  width  ...  stroke  \
# 195           front       109.1   188.8   68.9  ...    3.15
# 196           front       109.1   188.8   68.8  ...    3.15
# 197           front       109.1   188.8   68.9  ...    2.87
# 198           front       109.1   188.8   68.9  ...    3.40
# 199           front       109.1   188.8   68.9  ...    3.15
#
#      compression-ratio horsepower peak-rpm  city-mpg highway-L/100km    price  \
# ...

# %% [markdown]
# **Analysing individual feature patterns using visualisation**

# %%
#Finding correlation between bore, stroke, compression-ratio and horsepower
df[['bore', 'stroke', 'compression-ratio', 'horsepower']].corr()
# Out:
#                        bore    stroke  compression-ratio  horsepower
# bore               1.000000 -0.051087           0.002021    0.566690
# stroke            -0.051087  1.000000           0.186761    0.100351
# compression-ratio  0.002021  0.186761           1.000000   -0.214162
# horsepower         0.566690  0.100351          -0.214162    1.000000

# %%
# Finding correlation between stroke and price

df[["stroke","price"]].corr()
# Out:
#           stroke     price
# stroke  1.000000  0.083296
# price   0.083296  1.000000

# %%
#plotting correlation
import seaborn as sns
sns.regplot(x="stroke", y="price", data=df)
# Out:
# <Axes: xlabel='stroke', ylabel='price'>

# %% [markdown]
# Shows weak correlation between these 2 variables - regression will not work well

# %% [markdown]
# **Categorical Variables**

# %%
sns.boxplot(x="body-style", y="price", data=df)
# Out:
# <Axes: xlabel='body-style', ylabel='price'>

# %% [markdown]
# Distribution of price between different body-styles overlap - so would NOT be a good indicator of price

# %%
sns.boxplot(x="engine-location", y="price", data=df)
# Out:
# <Axes: xlabel='engine-location', ylabel='price'>

# %% [markdown]
# Distribution of price between engine-location are distinct so is a good indicator of price

# %%
sns.boxplot(x="drive-wheels", y="price", data=df)
# Out:
# <Axes: xlabel='drive-wheels', ylabel='price'>

# %% [markdown]
# Distribution varies with drive-wheel so could potentially be a good indicator

# %% [markdown]
# **Value Counts**

# %%
drive_wheels_counts = df['drive-wheels'].value_counts().to_frame()
drive_wheels_counts.reset_index(inplace=True)
drive_wheels_counts=drive_wheels_counts.rename(columns={'drive-wheels': 'value_counts'})
drive_wheels_counts

drive_wheels_counts.index.name = 'drive-wheels'
drive_wheels_counts
# Out:
#              value_counts  count
# drive-wheels
# 0                     fwd    118
# 1                     rwd     74
# 2                     4wd      8

# %%
# engine-location as variable
engine_loc_counts = df['engine-location'].value_counts().to_frame()
engine_loc_counts.rename(columns={'engine-location': 'value_counts'}, inplace=True)
engine_loc_counts.index.name = 'engine-location'
engine_loc_counts.head(10)
# Out:
#                  count
# engine-location
# front              197
# rear                 3

# %% [markdown]
# **Group by**

# %%
# grouping by drive-wheels
df['drive-wheels'].unique()
# Out:
# array(['rwd', 'fwd', '4wd'], dtype=object)

# %%
df_group_one = df[['drive-wheels','body-style','price']]

# grouping results
df_grouped = df_group_one.groupby(['drive-wheels'], as_index=False).agg({'price': 'mean'})
df_grouped
# Out:
#   drive-wheels         price
# 0          4wd  10241.000000
# 1          fwd   9244.779661
# 2          rwd  19842.243243

# %%
# grouping results
df_gptest = df[['drive-wheels','body-style','price']]
grouped_test1 = df_gptest.groupby(['drive-wheels','body-style'],as_index=False).mean()
grouped_test1
# Out:
#    drive-wheels   body-style         price
# 0           4wd    hatchback   7603.000000
# 1           4wd        sedan  12647.333333
# 2           4wd        wagon   9095.750000
# 3           fwd  convertible  11595.000000
# 4           fwd      hardtop   8249.000000
# 5           fwd    hatchback   8396.387755
# 6           fwd        sedan   9811.800000
# 7           fwd        wagon   9997.333333
# 8           rwd  convertible  26563.250000
# 9           rwd      hardtop  24202.714286
# 10          rwd    hatchback  14337.777778
# 11          rwd        sedan  21711.833333
# 12          rwd        wagon  16994.222222

# %%
grouped_pivot = grouped_test1.pivot(index='drive-wheels',columns='body-style')
grouped_pivot
# Out:
#                    price                                            \
# body-style   convertible       hardtop     hatchback         sedan
# drive-wheels
# 4wd                  NaN           NaN   7603.000000  12647.333333
# fwd             11595.00   8249.000000   8396.387755   9811.800000
# rwd             26563.25  24202.714286  14337.777778  21711.833333
#
#
# body-style           wagon
# drive-wheels
# 4wd            9095.750000
# fwd            9997.333333
# rwd           16994.222222

# %%
plt.pcolor(grouped_pivot, cmap='RdBu')
plt.colorbar()
plt.show()
# Out:
# C:\Users\vikra\AppData\Local\Temp\ipykernel_19644\1005740365.py:2: MatplotlibDeprecationWarning: Getting the array from a PolyQuadMesh will return the full array in the future (uncompressed). To get this behavior now set the PolyQuadMesh with a 2D array .set_array(data2d).
#   plt.colorbar()

# %%
fig, ax = plt.subplots()
im = ax.pcolor(grouped_pivot, cmap='RdBu')

#label names
row_labels = grouped_pivot.columns.levels[1]
col_labels = grouped_pivot.index

#move ticks and labels to the center
ax.set_xticks(np.arange(grouped_pivot.shape[1]) + 0.5, minor=False)
ax.set_yticks(np.arange(grouped_pivot.shape[0]) + 0.5, minor=False)

#insert labels
ax.set_xticklabels(row_labels, minor=False)
ax.set_yticklabels(col_labels, minor=False)

#rotate label if too long
plt.xticks(rotation=90)

fig.colorbar(im)
plt.show()
# Out:
# C:\Users\vikra\AppData\Local\Temp\ipykernel_19644\3671695375.py:19: MatplotlibDeprecationWarning: Getting the array from a PolyQuadMesh will return the full array in the future (uncompressed). To get this behavior now set the PolyQuadMesh with a 2D array .set_array(data2d).
#   fig.colorbar(im)

# %% [markdown]
# Gives easy to understand visualisation of price with 2 variables

# %% [markdown]
# **Correlation and Causation**

# %%
# Using Pearsons Correlation to calculate Pearsons Correlation Coefficient and p-value for 'wheel-base' and 'price'
from scipy import stats

pearson_coef, p_value = stats.pearsonr(df['wheel-base'], df['price'])
print("The Pearson Correlation Coefficient is", pearson_coef, " with a P-value of P =", p_value)
# Out:
# The Pearson Correlation Coefficient is 0.5891470005448702  with a P-value of P = 4.457019502050271e-20

# %% [markdown]
# Since the p-value is < 0.001 the correlation is statistically significant, however due to the PCC being close to 0 shows not a strong linear relationship

# %%
# Finding Correlation between 'width' and 'price'
pearson_coef, p_value = stats.pearsonr(df['width'], df['price'])
print("The Pearson Correlation Coefficient is", pearson_coef, " with a P-value of P =", p_value )
# Out:
# The Pearson Correlation Coefficient is 0.7527948631832608  with a P-value of P = 8.256714148308725e-38

# %% [markdown]
# p-value < 0.001 so correlation significant, PCC is relatively high so shows moderate linear relationship

# %%
# Finding Correlation between 'engine-size' and 'price'
pearson_coef, p_value = stats.pearsonr(df['engine-size'], df['price'])
print("The Pearson Correlation Coefficient is", pearson_coef, " with a P-value of P =", p_value)
# Out:
# The Pearson Correlation Coefficient is 0.8723367498521142  with a P-value of P = 1.8977171466561833e-63

# %% [markdown]
# p-value shows significance and PCC demonstrates strong linear relationship

# %% [markdown]
# **Linear Regression and Multiple Linear Regression**

# %%
# Building a linear regression model with 'engine-size' as the independent variable and 'price' as the dependent variable
from sklearn.linear_model import LinearRegression

lm.fit(df[['engine-size']], df[['price']])
lm

X = df[['engine-size']]
Y = df['price']

lm.fit(X,Y)
# Out:
# LinearRegression()

# %%
# finding slope
lm.coef_
# Out:
# array([166.8621392])

# %%
#finding intercept 
lm.intercept_
# Out:
# -7962.440979163099

# %%
#using Yhat = a + b  X to get equation of predicted line

Yhat=-7962.44 + 166.86*X

Price=-7962.44 + 166.86*df['engine-size']

# %% [markdown]
# **Multiple Linear Regression**

# %%
# Creating a multiple linear regression model based of 4 variable predictors (Z)
Z = df[['horsepower', 'curb-weight', 'engine-size', 'highway-L/100km']]

# %%
#Fit the model
lm.fit(Z, df['price'])
# Out:
# LinearRegression()

# %%
#Find intercept
lm.intercept_
# Out:
# -14380.274344442389

# %%
# Finding coefficient
lm.coef_
# Out:
# array([ 36.74807279,   3.49571047,  85.33194672, 500.97246527])

# %% [markdown]
# **Model Evalusation using Visualisation**

# %%
# Visualising highway-L/100km as a predictor for price using regression plots
width = 12
height = 10
plt.figure(figsize=(width, height))
sns.regplot(x="highway-L/100km", y="price", data=df)
plt.ylim(0,)
# Out:
# (0.0, 47719.806994554536)

# %% [markdown]
# We can see a positive correleation - however points are scattered a lot

# %%
# Comparing against regression plt of peak-rpm with price
plt.figure(figsize=(width, height))
sns.regplot(x="peak-rpm", y="price", data=df)
plt.ylim(0,)
# Out:
# (0.0, 47414.1)

# %% [markdown]
# We can see slight negative correlation but cannot tell for sure
# Highway-L/100km points are a lot closer to the line than peak-rpm

# %% [markdown]
# **Residual Plotting**

# %%
width = 12
height = 10
plt.figure(figsize=(width, height))
sns.residplot(x=df['highway-L/100km'], y=df['price'])
plt.show()

# %% [markdown]
# Residual plot shows us points are not randomly spread around x axis - showing that a non-linear model is more appropriate

# %% [markdown]
# **Visualising Multiple Linear Regression**

# %%
# Making Prediction
Y_hat = lm.predict(Z)

# %%
plt.figure(figsize=(width, height))


ax1 = sns.distplot(df['price'], hist=False, color="r", label="Actual Value")
sns.distplot(Y_hat, hist=False, color="b", label="Fitted Values" , ax=ax1)


plt.title('Actual vs Fitted Values for Price')
plt.xlabel('Price (in dollars)')
plt.ylabel('Proportion of Cars')

plt.show()
plt.close()
# Out:
# C:\Users\vikra\AppData\Local\Temp\ipykernel_19644\4196657742.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax1 = sns.distplot(df['price'], hist=False, color="r", label="Actual Value")
# C:\Users\vikra\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\vikra\AppData\Local\Temp\ipykernel_19644\4196657742.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# ...

# %% [markdown]
# From plot we can see fitted values are reasonably close to actual but could be improved

# %% [markdown]
# **Polynomial Regression**

# %%
# Trying Polynomial regression for highway-L/100km

def PlotPolly(model, independent_variable, dependent_variabble, Name):
    x_new = np.linspace(5, 15, 25)
    y_new = model(x_new)

    plt.plot(independent_variable, dependent_variabble, '.', x_new, y_new, '-')
    plt.title('Polynomial Fit with Matplotlib for Price ~ highway-L/100km')
    ax = plt.gca()
    ax.set_facecolor((0.898, 0.898, 0.898))
    fig = plt.gcf()
    plt.xlabel(Name)
    plt.ylabel('Price of Cars')

    plt.show()
    plt.close()

# %%
#Variables
x = df['highway-L/100km']
y = df['price']

# %%
f = np.polyfit(x, y, 3)
p = np.poly1d(f)
print(p)
# Out:
#         3         2
# -23.38 x + 922.1 x - 7064 x + 2.145e+04

# %%
#Plotting the function
PlotPolly(p, x, y, 'highway-L/100km')
np.polyfit(x, y, 3)
# Out:
# array([  -23.37611329,   922.12919775, -7063.83725212, 21445.20344533])

# %% [markdown]
# Performs better than linear model
